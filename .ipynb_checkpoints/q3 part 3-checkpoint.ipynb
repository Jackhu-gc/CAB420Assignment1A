# %%
import tensorflow as tf
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from tensorboard import notebook
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras.utils import model_to_dot, plot_model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorboard import notebook

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import matplotlib.pyplot as plt

import scipy.io
import numpy
# numpy.set_printoptions(threshold=numpy.inf)

import os
import datetime
# import pydot
import IPython
from IPython.display import SVG
import matplotlib.pyplot as plt
import sys
import scipy.io
import numpy
import cv2
# pd.options.display.max_columns = None
# numpy.set_printoptions(threshold=sys.maxsize)

# %%
SVHN_train = scipy.io.loadmat(r'C:\Users\Callum\Desktop\cab420\CAB420Assignment1A\q3_train.mat')
SVHN_test = scipy.io.loadmat(r'C:\Users\Callum\Desktop\cab420\CAB420Assignment1A\q3_test.mat')

# %%
for i in range (len(SVHN_train['train_Y'])):
    if(SVHN_train['train_Y'][i] == 10):
        SVHN_train['train_Y'][i] = 0
    
    
    
for i in range (len(SVHN_test['test_Y'])):
    if(SVHN_test['test_Y'][i] == 10):
        SVHN_test['test_Y'][i] = 0
    
train_y = SVHN_train['train_Y']

test_y = SVHN_test['test_Y']    

# Do we need to preserve rbg value(3) in a 4D, or just put 1 in the end
train = numpy.transpose(SVHN_train['train_X'], (3, 0, 1, 2)).reshape(-1, 32, 32, 3)
test = numpy.transpose(SVHN_test['test_X'], (3, 0, 1, 2)).reshape(-1, 32, 32, 3)





print(SVHN_test['test_Y'].shape) 
print(train.shape)
fig = plt.figure(figsize=[10, 10])
for i in range(100):
    ax = fig.add_subplot(10, 10, i + 1)
    ax.imshow(train[i,:,:,:])
# Out:
# (10000, 1)
# (1000, 32, 32, 3)

# %%
def scale(data):
    train_trim = numpy.array(data)
    for i,elem1 in enumerate(train_trim[:2]):
        for x,elem2 in enumerate(elem1[:2]):
            for y,elem3 in enumerate(elem2[:2]): 
                gray = (0.3 * elem3[0]) + (0.59 * elem3[1]) + (0.11 * elem3[2])
#                 gray = gray/255
                train_trim[i,x,y] = gray
    train_trim = train_trim[:,:,:,2:]
    resized_ar = []
    for i,elem in enumerate(train_trim):
        width = 28
        height = 28
        dim = (width, height)
        resized = cv2.resize(elem, dim, interpolation = cv2.INTER_AREA)
        resized = resized.reshape(28,28,1)
        resized_ar.append(resized)
    resized_ar = numpy.array(resized_ar)  
    return resized_ar

  

resized_ar_train = scale(train)  
resized_ar_test = scale(test)    
for n in range(10):
    print(test_y[n])
# print(resized_ar_train.shape) 
# print(resized_ar_test.shape)

    
fig = plt.figure(figsize=[10, 10])
reresized_ar_train = resized_ar_train.reshape(1000,28,28)
reresized_ar_test = resized_ar_test.reshape(10000,28,28)

for i in range(50):
    ax = fig.add_subplot(10, 10, i+1)   
    ax.imshow(reresized_ar_train[i,:,:])    
    
# fig2 = plt.figure(figsize=[10, 10])

# for i in range(50):
#     ax = fig2.add_subplot(10, 10, i+1)   
#     ax.imshow(reresized_ar_train[i,:,:])
# Out:
# [5]
# [1]
# [1]
# [4]
# [0]
# [3]
# [4]
# [8]
# [8]
# [6]

# %%
model_mnist = keras.models.load_model(r'C:\Users\Callum\Desktop\cab420\CAB420Assignment1A\vgg_3stage_MNIST_bigger.h5')
model = model_mnist
model.summary()
# Out:
# Model: "simple_vgg"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img (InputLayer)             [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_29 (Activation)   (None, 28, 28, 16)        0
# _________________________________________________________________
# spatial_dropout2d_17 (Spatia (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 14, 14, 32)        4640
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 14, 14, 32)        128
# _________________________________________________________________
# activation_30 (Activation)   (None, 14, 14, 32)        0
# _________________________________________________________________
# spatial_dropout2d_18 (Spatia (None, 14, 14, 32)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# activation_31 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# spatial_dropout2d_19 (Spatia (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1024)              3212288
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 1024)              4096
# _________________________________________________________________
# activation_32 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               262400
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_33 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 3,554,618
# Trainable params: 3,551,834
# Non-trainable params: 2,784
# _________________________________________________________________

# %%
for layer in model.layers[:-21]:
    layer.trainable = False

for layer in model.layers:
    print(layer, layer.trainable)
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x0000013C41AFAA08> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013C41AFAE48> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013C41AF3488> False
# <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x0000013C41AF3E08> False
# <tensorflow.python.keras.layers.core.Activation object at 0x0000013C41B31708> False
# <tensorflow.python.keras.layers.core.SpatialDropout2D object at 0x0000013C41B31B08> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000013C41B31F88> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013C3F2EF8C8> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013C3EED8C48> True
# <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x0000013C41B2D288> True
# <tensorflow.python.keras.layers.core.Activation object at 0x0000013C41B2DB48> True
# <tensorflow.python.keras.layers.core.SpatialDropout2D object at 0x0000013C41B2DF48> True
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000013C41B2B448> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013C41B2B988> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013C41B2BFC8> True
# <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x0000013C41B2A648> True
# <tensorflow.python.keras.layers.core.Activation object at 0x0000013C41B2AF08> True
# <tensorflow.python.keras.layers.core.SpatialDropout2D object at 0x0000013C41B27348> True
# <tensorflow.python.keras.layers.core.Flatten object at 0x0000013C41B27808> True
# <tensorflow.python.keras.layers.core.Dense object at 0x0000013C41B27D08> True
# <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x0000013C41B25388> True
# <tensorflow.python.keras.layers.core.Activation object at 0x0000013C41B25BC8> True
# <tensorflow.python.keras.layers.core.Dropout object at 0x0000013C41B25FC8> True
# <tensorflow.python.keras.layers.core.Dense object at 0x0000013C41B21488> True
# <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x0000013C41B21AC8> True
# <tensorflow.python.keras.layers.core.Activation object at 0x0000013C41B1D348> True
# <tensorflow.python.keras.layers.core.Dropout object at 0x0000013C41B1D748> True
# <tensorflow.python.keras.layers.core.Dense object at 0x0000013C41B1DBC8> True

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',
                                                 numpy.unique(train_y.flatten()),
                                                 train_y.flatten())
print(class_weights)
# Out:
# [1.66666667 0.57142857 0.65359477 0.83333333 0.95238095 1.07526882
#  1.36986301 1.17647059 1.38888889 1.5625    ]

# %%
model.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])
print(test_y.shape)
history = model.fit(resized_ar_train, train_y,
                        batch_size=128,
                        epochs=25,
                        validation_data=(resized_ar_test, test_y),
                   class_weight=class_weights)
# Out:
# (10000, 1)
# Train on 1000 samples, validate on 10000 samples
# Epoch 1/25
# 1000/1000 [==============================] - 5s 5ms/sample - loss: 5.0580 - accuracy: 0.3760 - val_loss: 402.3291 - val_accuracy: 0.3695
# Epoch 2/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 2.7942 - accuracy: 0.4940 - val_loss: 542.1063 - val_accuracy: 0.3442
# Epoch 3/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 1.9344 - accuracy: 0.5870 - val_loss: 407.0126 - val_accuracy: 0.4222
# Epoch 4/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 1.6038 - accuracy: 0.6040 - val_loss: 373.1368 - val_accuracy: 0.4303
# Epoch 5/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 1.3645 - accuracy: 0.6470 - val_loss: 320.5600 - val_accuracy: 0.4548
# Epoch 6/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 1.1827 - accuracy: 0.6740 - val_loss: 310.7200 - val_accuracy: 0.4345
# Epoch 7/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 1.0774 - accuracy: 0.7110 - val_loss: 287.2827 - val_accuracy: 0.4603
# Epoch 8/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.9040 - accuracy: 0.7300 - val_loss: 272.4676 - val_accuracy: 0.4656
# Epoch 9/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.8640 - accuracy: 0.7220 - val_loss: 303.7086 - val_accuracy: 0.4695
# Epoch 10/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.7543 - accuracy: 0.7710 - val_loss: 283.9005 - val_accuracy: 0.4724
# Epoch 11/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.7269 - accuracy: 0.7810 - val_loss: 219.0956 - val_accuracy: 0.4803
# Epoch 12/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.6991 - accuracy: 0.8060 - val_loss: 193.5078 - val_accuracy: 0.4645
# Epoch 13/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5917 - accuracy: 0.8160 - val_loss: 187.6384 - val_accuracy: 0.4577
# Epoch 14/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5613 - accuracy: 0.8270 - val_loss: 194.9910 - val_accuracy: 0.4751
# Epoch 15/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.4891 - accuracy: 0.8390 - val_loss: 187.8973 - val_accuracy: 0.4733
# Epoch 16/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.5032 - accuracy: 0.8440 - val_loss: 174.8564 - val_accuracy: 0.4926
# Epoch 17/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.4382 - accuracy: 0.8490 - val_loss: 176.2344 - val_accuracy: 0.4921
# Epoch 18/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.3909 - accuracy: 0.8620 - val_loss: 174.9445 - val_accuracy: 0.5123
# Epoch 19/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.3558 - accuracy: 0.8710 - val_loss: 168.8059 - val_accuracy: 0.5097
# Epoch 20/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.3736 - accuracy: 0.8800 - val_loss: 172.8892 - val_accuracy: 0.5100
# Epoch 21/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.2970 - accuracy: 0.8940 - val_loss: 206.6354 - val_accuracy: 0.5010
# Epoch 22/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.3063 - accuracy: 0.9130 - val_loss: 187.3139 - val_accuracy: 0.5148
# Epoch 23/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.2810 - accuracy: 0.9070 - val_loss: 136.5142 - val_accuracy: 0.5499
# Epoch 24/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.2431 - accuracy: 0.9320 - val_loss: 132.8898 - val_accuracy: 0.5544
# Epoch 25/25
# 1000/1000 [==============================] - 4s 4ms/sample - loss: 0.2065 - accuracy: 0.9370 - val_loss: 128.1365 - val_accuracy: 0.5592

# %% [markdown]
# With Class Weights

# %%
def eval_model(model, x_test, y_test):
    test_scores = model.evaluate(x_test, y_test, verbose=2)
    print('Test loss:', test_scores[0])
    print('Test accuracy:', test_scores[1])

    pred = model.predict(x_test);
    indexes = tf.argmax(pred, axis=1)

    cm = confusion_matrix(y_test, indexes)
    fig = plt.figure(figsize=[20, 6])
    ax = fig.add_subplot(1, 2, 1)
    c = ConfusionMatrixDisplay(cm, display_labels=range(10))
    c.plot(ax = ax)

    ax = fig.add_subplot(1, 2, 2)
    ax.hist(y_test, bins=len(numpy.diagonal(cm)), rwidth=0.95)
    ax.plot(numpy.diagonal(cm))

# %%
eval_model(model, resized_ar_test, test_y)
print()
# Out:
# 10000/10000 - 5s - loss: 0.6439 - accuracy: 0.8205
# Test loss: 0.6439042216300964
# Test accuracy: 0.8205
