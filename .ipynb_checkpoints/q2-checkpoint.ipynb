# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.svm import SVC, NuSVC
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from scipy.stats import norm

# %%
train_spectral = pd.read_csv(r'C:\Users\Callum\Documents\cab420-assignment1a\CAB420Assignment1A\training.csv')
test_spectral = pd.read_csv(r'C:\Users\Callum\Documents\cab420-assignment1a\CAB420Assignment1A\testing.csv')

# %%
print(train_spectral.head())
# Out:
#   class  b1  b2  b3   b4  b5   b6   b7  b8  b9  ...  pred_minus_obs_H_b9  \
# 0    d   39  36  57   91  59  101   93  27  60  ...                -2.36
# 1    h   84  30  57  112  51   98   92  26  62  ...                -2.26
# 2    s   53  25  49   99  51   93   84  26  58  ...                -1.46
# 3    s   59  26  49  103  47   92   82  25  56  ...                 2.68
# 4    d   57  49  66  103  64  106  114  28  59  ...                -2.94
#
#    pred_minus_obs_S_b1  pred_minus_obs_S_b2  pred_minus_obs_S_b3  \
# 0               -18.41                -1.88                -6.43
# 1               -16.27                -1.95                -6.25
# 2               -15.92                -1.79                -4.64
# 3               -13.77                -2.53                -6.34
# 4               -21.74                -1.64                -4.62
#
#    pred_minus_obs_S_b4  pred_minus_obs_S_b5  pred_minus_obs_S_b6  \
# 0               -21.03                -1.60                -6.18
# 1               -18.79                -1.99                -6.18
# 2               -17.73                -0.48                -4.69
# 3               -22.03                -2.34                -6.60
# 4               -23.74                -0.85                -5.50
#
#    pred_minus_obs_S_b7  pred_minus_obs_S_b8  pred_minus_obs_S_b9
# 0               -22.50                -5.20                -7.86
# 1               -23.41                -8.87               -10.83
# 2               -19.97                -4.10                -7.07
# 3               -27.10                -7.99               -10.81
# 4               -22.83                -2.74                -5.84
#
# [5 rows x 28 columns]

# %%
print(test_spectral.head())
# Out:
#   class  b1  b2  b3   b4  b5   b6   b7  b8  b9  ...  pred_minus_obs_H_b9  \
# 0    d   67  51  68  115  69  111  136  31  67  ...                -9.17
# 1    s   67  28  51   99  50   97   82  26  59  ...                -2.25
# 2    s   63  26  50   95  49   91   81  26  57  ...                -0.44
# 3    d   63  42  63   97  66  108  111  28  59  ...                -2.34
# 4    s   46  27  50   83  51   90   76  26  56  ...                 1.25
#
#    pred_minus_obs_S_b1  pred_minus_obs_S_b2  pred_minus_obs_S_b3  \
# 0               -18.27                -1.80                -6.32
# 1               -20.13                -2.11                -6.35
# 2               -17.64                -1.81                -4.70
# 3               -20.20                -1.89                -5.47
# 4               -18.62                -2.17                -7.11
#
#    pred_minus_obs_S_b4  pred_minus_obs_S_b5  pred_minus_obs_S_b6  \
# 0               -20.88                -1.63                -6.13
# 1               -21.94                -1.22                -6.13
# 2               -19.39                -0.65                -5.01
# 3               -21.65                -0.99                -5.71
# 4               -21.12                -1.56                -6.35
#
#    pred_minus_obs_S_b7  pred_minus_obs_S_b8  pred_minus_obs_S_b9
# 0               -22.56                -5.53                -8.11
# 1               -22.20                -3.41                -6.57
# 2               -20.89                -3.96                -6.85
# 3               -22.19                -3.41                -6.52
# 4               -22.19                -4.45                -7.32
#
# [5 rows x 28 columns]

# %%
test_spectral['class'] = pd.Categorical(test_spectral['class'])
train_spectral['class'] = pd.Categorical(train_spectral['class'])

predictionColumn_test = test_spectral['class']
predictors_test = test_spectral.drop('class', axis=1)

Y_train = train_spectral['class']
X_train = train_spectral.drop('class', axis=1)

X_test, X_val, Y_test, Y_val = train_test_split(predictors_test, predictionColumn_test, test_size=0.8, random_state=1)

# %%
import matplotlib.pyplot as plt
spectral_hist = plt.hist(train_spectral['class']) 
plt.title("Histogram with spectral")
plt.show()

# %% [markdown]
# Good spread, smaller number of '0' but enough to not make too much of a difference

# %%
def eval_model(model, X_train, Y_train, X_test, Y_test, graphs):
    if(graphs):
        fig = plt.figure(figsize=[25, 8])
        ax = fig.add_subplot(1, 2, 1)
        conf = plot_confusion_matrix(model, X_train, Y_train, normalize='true', ax=ax)
        conf.ax_.set_title('Training Set Performance');
        ax = fig.add_subplot(1, 2, 2)
        conf = plot_confusion_matrix(model, X_test, Y_test, normalize='true', ax=ax)
        conf.ax_.set_title('Validation Test Set Performance');
    pred = model.predict(X_test)
    print(classification_report(Y_test, pred)) 
    return str(sum(pred == Y_test)/len(Y_test))

# %%
#Make the model using random n_neighbours and distance to show that it works
cknn = KNeighborsClassifier(n_neighbors=9, weights='distance')
cknn.fit(X_train, Y_train)
test_accur = eval_model(cknn, X_train, Y_train, X_val, Y_val, True)
print("Test Accuracy: ", test_accur)
# Out:
#               precision    recall  f1-score   support
#
#           d        0.85      0.79      0.82        85
#           h        0.71      0.76      0.74        33
#           o        0.80      0.65      0.71        31
#           s        0.81      0.88      0.84       111
#
#     accuracy                           0.81       260
#    macro avg       0.79      0.77      0.78       260
# weighted avg       0.81      0.81      0.81       260
#
# Test Accuracy:  0.8076923076923077

# %% [markdown]
# Not too bad, this model is using distance weight and n_neighbors is set at 9. We always want to use an odd number for n_beighbours so there will never be a tie in neighbours.
# We can try to optimize this to find the best combination of the hyperparamters.

# %%
test_accuracy = {}
x_dist = []
y_dist = []
x_nodist = []
y_nodist = []
for i in range(1, 30, 2):
    for x in range(0,2):
        if(x == 0):
            cknn = KNeighborsClassifier(n_neighbors=i, weights='distance')
        else:
            cknn = KNeighborsClassifier(n_neighbors=i)
        cknn.fit(X_train, Y_train)
        test_accur = eval_model(cknn, X_train, Y_train, X_val, Y_val, False)
        if(x == 0):
            test_accuracy[i, "Dist"] = (test_accur)
            x_dist.append(i)
            y_dist.append(float(test_accur))
        else:
            test_accuracy[i, "No Dist"] = (test_accur)
            x_nodist.append(i)
            y_nodist.append(float(test_accur))

print(test_accuracy)
import operator
max(test_accuracy.items(), key=operator.itemgetter(1))[0]
# Out:
#               precision    recall  f1-score   support
#
#           d        0.86      0.91      0.88        85
#           h        0.79      0.79      0.79        33
#           o        0.87      0.65      0.74        31
#           s        0.89      0.91      0.90       111
#
#     accuracy                           0.86       260
#    macro avg       0.85      0.81      0.83       260
# weighted avg       0.86      0.86      0.86       260
#
#               precision    recall  f1-score   support
#
#           d        0.86      0.91      0.88        85
#           h        0.79      0.79      0.79        33
#           o        0.87      0.65      0.74        31
#           s        0.89      0.91      0.90       111
#
#     accuracy                           0.86       260
#    macro avg       0.85      0.81      0.83       260
# weighted avg       0.86      0.86      0.86       260
#
#               precision    recall  f1-score   support
#
#           d        0.85      0.82      0.84        85
#           h        0.76      0.79      0.78        33
#           o        0.81      0.68      0.74        31
#           s        0.85      0.90      0.87       111
#
#     accuracy                           0.83       260
#    macro avg       0.82      0.80      0.81       260
# weighted avg       0.83      0.83      0.83       260
#
#               precision    recall  f1-score   support
#
#           d        0.85      0.82      0.84        85
#           h        0.76      0.79      0.78        33
#           o        0.81      0.68      0.74        31
#           s        0.85      0.90      0.87       111
#
#     accuracy                           0.83       260
#    macro avg       0.82      0.80      0.81       260
# weighted avg       0.83      0.83      0.83       260
#
#               precision    recall  f1-score   support
#
#           d        0.85      0.78      0.81        85
#           h        0.74      0.79      0.76        33
#           o        0.80      0.65      0.71        31
#           s        0.82      0.90      0.86       111
#
#     accuracy                           0.82       260
#    macro avg       0.80      0.78      0.79       260
# weighted avg       0.82      0.82      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.85      0.78      0.81        85
#           h        0.74      0.79      0.76        33
#           o        0.80      0.65      0.71        31
#           s        0.82      0.90      0.86       111
#
#     accuracy                           0.82       260
#    macro avg       0.80      0.78      0.79       260
# weighted avg       0.82      0.82      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.84      0.78      0.80        85
#           h        0.71      0.76      0.74        33
#           o        0.80      0.65      0.71        31
#           s        0.82      0.89      0.85       111
#
#     accuracy                           0.81       260
#    macro avg       0.79      0.77      0.78       260
# weighted avg       0.81      0.81      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.84      0.78      0.80        85
#           h        0.71      0.76      0.74        33
#           o        0.80      0.65      0.71        31
#           s        0.82      0.89      0.85       111
#
#     accuracy                           0.81       260
#    macro avg       0.79      0.77      0.78       260
# weighted avg       0.81      0.81      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.85      0.79      0.82        85
#           h        0.71      0.76      0.74        33
#           o        0.80      0.65      0.71        31
#           s        0.81      0.88      0.84       111
#
#     accuracy                           0.81       260
#    macro avg       0.79      0.77      0.78       260
# weighted avg       0.81      0.81      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.85      0.79      0.82        85
#           h        0.71      0.76      0.74        33
#           o        0.80      0.65      0.71        31
#           s        0.81      0.88      0.84       111
#
#     accuracy                           0.81       260
#    macro avg       0.79      0.77      0.78       260
# weighted avg       0.81      0.81      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.86      0.76      0.81        85
#           h        0.71      0.76      0.74        33
#           o        0.83      0.65      0.73        31
#           s        0.80      0.90      0.85       111
#
#     accuracy                           0.81       260
#    macro avg       0.80      0.77      0.78       260
# weighted avg       0.81      0.81      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.86      0.76      0.81        85
#           h        0.71      0.76      0.74        33
#           o        0.83      0.65      0.73        31
#           s        0.80      0.90      0.85       111
#
#     accuracy                           0.81       260
#    macro avg       0.80      0.77      0.78       260
# weighted avg       0.81      0.81      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.87      0.76      0.81        85
#           h        0.72      0.79      0.75        33
#           o        0.83      0.65      0.73        31
#           s        0.81      0.91      0.86       111
#
#     accuracy                           0.82       260
#    macro avg       0.81      0.78      0.79       260
# weighted avg       0.82      0.82      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.87      0.78      0.82        85
#           h        0.72      0.79      0.75        33
#           o        0.87      0.65      0.74        31
#           s        0.81      0.91      0.86       111
#
#     accuracy                           0.82       260
#    macro avg       0.82      0.78      0.79       260
# weighted avg       0.82      0.82      0.82       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.79      0.83        85
#           h        0.72      0.79      0.75        33
#           o        0.91      0.65      0.75        31
#           s        0.80      0.91      0.85       111
#
#     accuracy                           0.82       260
#    macro avg       0.83      0.78      0.80       260
# weighted avg       0.83      0.82      0.82       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.76      0.82        85
#           h        0.72      0.79      0.75        33
#           o        0.87      0.65      0.74        31
#           s        0.80      0.91      0.85       111
#
#     accuracy                           0.82       260
#    macro avg       0.82      0.78      0.79       260
# weighted avg       0.82      0.82      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.78      0.82        85
#           h        0.73      0.82      0.77        33
#           o        0.91      0.65      0.75        31
#           s        0.80      0.91      0.85       111
#
#     accuracy                           0.82       260
#    macro avg       0.83      0.79      0.80       260
# weighted avg       0.83      0.82      0.82       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.76      0.82        85
#           h        0.73      0.82      0.77        33
#           o        0.87      0.65      0.74        31
#           s        0.80      0.91      0.85       111
#
#     accuracy                           0.82       260
#    macro avg       0.82      0.78      0.80       260
# weighted avg       0.83      0.82      0.82       260
#
#               precision    recall  f1-score   support
#
#           d        0.89      0.78      0.83        85
#           h        0.76      0.85      0.80        33
#           o        0.91      0.65      0.75        31
#           s        0.80      0.92      0.86       111
#
#     accuracy                           0.83       260
#    macro avg       0.84      0.80      0.81       260
# weighted avg       0.84      0.83      0.83       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.76      0.82        85
#           h        0.76      0.85      0.80        33
#           o        0.86      0.61      0.72        31
#           s        0.80      0.92      0.86       111
#
#     accuracy                           0.82       260
#    macro avg       0.83      0.79      0.80       260
# weighted avg       0.83      0.82      0.82       260
#
#               precision    recall  f1-score   support
#
#           d        0.89      0.78      0.83        85
#           h        0.75      0.82      0.78        33
#           o        0.91      0.65      0.75        31
#           s        0.80      0.92      0.85       111
#
#     accuracy                           0.83       260
#    macro avg       0.84      0.79      0.81       260
# weighted avg       0.84      0.83      0.83       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.75      0.81        85
#           h        0.75      0.82      0.78        33
#           o        0.86      0.61      0.72        31
#           s        0.79      0.92      0.85       111
#
#     accuracy                           0.82       260
#    macro avg       0.82      0.78      0.79       260
# weighted avg       0.82      0.82      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.78      0.82        85
#           h        0.75      0.82      0.78        33
#           o        0.90      0.61      0.73        31
#           s        0.80      0.92      0.85       111
#
#     accuracy                           0.82       260
#    macro avg       0.83      0.78      0.80       260
# weighted avg       0.83      0.82      0.82       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.74      0.80        85
#           h        0.75      0.82      0.78        33
#           o        0.86      0.61      0.72        31
#           s        0.78      0.92      0.85       111
#
#     accuracy                           0.81       260
#    macro avg       0.82      0.77      0.79       260
# weighted avg       0.82      0.81      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.76      0.82        85
#           h        0.76      0.85      0.80        33
#           o        0.90      0.61      0.73        31
#           s        0.80      0.92      0.85       111
#
#     accuracy                           0.82       260
#    macro avg       0.83      0.79      0.80       260
# weighted avg       0.83      0.82      0.82       260
#
#               precision    recall  f1-score   support
#
#           d        0.87      0.73      0.79        85
#           h        0.76      0.85      0.80        33
#           o        0.86      0.61      0.72        31
#           s        0.78      0.92      0.85       111
#
#     accuracy                           0.81       260
#    macro avg       0.82      0.78      0.79       260
# weighted avg       0.82      0.81      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.88      0.74      0.80        85
#           h        0.76      0.85      0.80        33
#           o        0.90      0.61      0.73        31
#           s        0.78      0.92      0.85       111
#
#     accuracy                           0.82       260
#    macro avg       0.83      0.78      0.79       260
# weighted avg       0.82      0.82      0.81       260
#
#               precision    recall  f1-score   support
#
#           d        0.87      0.71      0.78        85
#           h        0.76      0.85      0.80        33
#           o        0.90      0.61      0.73        31
#           s        0.77      0.92      0.84       111
#
#     accuracy                           0.80       260
#    macro avg       0.82      0.77      0.79       260
# weighted avg       0.82      0.80      0.80       260
#               precision    recall  f1-score   support
#
#           d        0.87      0.72      0.79        85
#           h        0.76      0.85      0.80        33
#           o        0.90      0.61      0.73        31
#           s        0.77      0.92      0.84       111
#
#     accuracy                           0.81       260
#    macro avg       0.83      0.77      0.79       260
# weighted avg       0.82      0.81      0.80       260
#
#               precision    recall  f1-score   support
#
#           d        0.87      0.72      0.79        85
#           h        0.76      0.85      0.80        33
#           o        0.95      0.61      0.75        31
#           s        0.77      0.92      0.84       111
#
#     accuracy                           0.81       260
#    macro avg       0.84      0.77      0.79       260
# weighted avg       0.82      0.81      0.80       260
#
# {(1, 'Dist'): '0.8615384615384616', (1, 'No Dist'): '0.8615384615384616', (3, 'Dist'): '0.8346153846153846', (3, 'No Dist'): '0.8346153846153846', (5, 'Dist'): '0.8153846153846154', (5, 'No Dist'): '0.8153846153846154', (7, 'Dist'): '0.8076923076923077', (7, 'No Dist'): '0.8076923076923077', (9, 'Dist'): '0.8076923076923077', (9, 'No Dist'): '0.8076923076923077', (11, 'Dist'): '0.8076923076923077', (11, 'No Dist'): '0.8076923076923077', (13, 'Dist'): '0.8153846153846154', (13, 'No Dist'): '0.8192307692307692', (15, 'Dist'): '0.823076923076923', (15, 'No Dist'): '0.8153846153846154', (17, 'Dist'): '0.823076923076923', (17, 'No Dist'): '0.8192307692307692', (19, 'Dist'): '0.8307692307692308', (19, 'No Dist'): '0.823076923076923', (21, 'Dist'): '0.8269230769230769', (21, 'No Dist'): '0.8153846153846154', (23, 'Dist'): '0.823076923076923', (23, 'No Dist'): '0.8115384615384615', (25, 'Dist'): '0.823076923076923', (25, 'No Dist'): '0.8115384615384615', (27, 'Dist'): '0.8153846153846154', (27, 'No Dist'): '0.8038461538461539', (29, 'Dist'): '0.8076923076923077', (29, 'No Dist'): '0.8076923076923077'}
# (1, 'Dist')

# %%
plt.figure(figsize=(10,10))

plt.plot(x_dist, y_dist, label='Distance Weight', marker='x' )
plt.plot(x_nodist, y_nodist, label='No Distance Weight', marker='o' )
plt.ylabel('Test Accruacy') 
plt.xlabel('n_neighbours') 
plt.annotate('(19, 0.83076)', xy=(19, 0.8307692307692308))
plt.legend()

plt.show()

# %% [markdown]
# Here we see that using the n_neighbors value of 1 is the most optimal for always ascribing the data to the correct group. But, this is not what we want because this is overfitting the data. Instead we have decided to go with n_neighbours as 19 as it is high enough to not be overfitting and has a fairly decent accuracy for predicting the classes. We did see an increase in accuracy with the distance weight too. Here is the confusion matrix for 19 and test accuracy for testing data.

# %%
#Make the model
cknn = KNeighborsClassifier(n_neighbors=19, weights='distance' )
cknn.fit(X_train, Y_train)
test_accur = eval_model(cknn, X_train, Y_train, X_test, Y_test, True)
print("Test Accuracy: ", test_accur)
# Out:
#               precision    recall  f1-score   support
#
#           d        0.88      0.75      0.81        20
#           h        0.71      1.00      0.83         5
#           o        0.92      0.80      0.86        15
#           s        0.82      0.92      0.87        25
#
#     accuracy                           0.85        65
#    macro avg       0.84      0.87      0.84        65
# weighted avg       0.86      0.85      0.85        65
#
# Test Accuracy:  0.8461538461538461

# %%
#This is the automated way of doing this
from sklearn.model_selection import GridSearchCV
#create new a knn model
knn2 = KNeighborsClassifier()
#create a dictionary of all values we want to test for n_neighbors
param_grid = {'n_neighbors': np.arange(1, 25), 'weights': ['distance', 'uniform']}
#use gridsearch to test all values for n_neighbors
knn_gscv = GridSearchCV(knn2, param_grid, cv=5)
#fit model to data
knn_gscv.fit(X_train, Y_train)
#check top performing n_neighbors value

predictions = knn_gscv.predict(X_test) 
print(classification_report(Y_test, predictions)) 

knn_gscv.best_params_
# Out:
#               precision    recall  f1-score   support
#
#           d        0.89      0.85      0.87        20
#           h        0.62      1.00      0.77         5
#           o        0.86      0.80      0.83        15
#           s        0.96      0.92      0.94        25
#
#     accuracy                           0.88        65
#    macro avg       0.83      0.89      0.85        65
# weighted avg       0.89      0.88      0.88        65
# {'n_neighbors': 1, 'weights': 'distance'}

# %% [markdown]
# This automated way produces the same result

# %% [markdown]
# ## One vs. One

# %%
svm = SVC()
svm.fit(X_train, Y_train)
eval_model(svm, X_train, Y_train, X_test, Y_test, True)
# Out:
#               precision    recall  f1-score   support
#
#           d        0.82      0.70      0.76        20
#           h        0.62      1.00      0.77         5
#           o        0.92      0.73      0.81        15
#           s        0.82      0.92      0.87        25
#
#     accuracy                           0.82        65
#    macro avg       0.80      0.84      0.80        65
# weighted avg       0.83      0.82      0.81        65
# '0.8153846153846154'

# %%
svm = SVC(class_weight='balanced')
svm.fit(X_train, Y_train)
eval_model(svm, X_train, Y_train, X_test, Y_test, True)
# Out:
#               precision    recall  f1-score   support
#
#           d        0.88      0.70      0.78        20
#           h        0.62      1.00      0.77         5
#           o        0.92      0.80      0.86        15
#           s        0.82      0.92      0.87        25
#
#     accuracy                           0.83        65
#    macro avg       0.81      0.85      0.82        65
# weighted avg       0.85      0.83      0.83        65
# '0.8307692307692308'

# %%
estimator__kernel = [ 'rbf']
gamma_values = ['scale', 'auto']
accuracy_max = 0
accur_obj = {}
x_scale=[]
y_scale = []

for i in range(1,50):
     for y,gammas in enumerate(gamma_values):
        for x,elem in enumerate(estimator__kernel):
            search = SVC(class_weight='balanced', C=i, kernel=elem, gamma = gammas)
            search.fit(X_train, Y_train)
            predicted = search.predict(X_test)
            accur = accuracy_score(Y_test, predicted)
            if(gammas == 'scale'):
                x_scale.append(i)
                y_scale.append(accur)
           
            if(accur > accuracy_max):
                best = search
                accuracy_max = accur
                name = "C:" , i+1, " Kernel: ", elem , " Gamma: ", gammas
                accur_obj = {name: accuracy_max}
eval_model(best, X_train, Y_train, X_test, Y_test, True)


print(accur_obj)
# Out:
#               precision    recall  f1-score   support
#
#           d        0.94      0.80      0.86        20
#           h        0.71      1.00      0.83         5
#           o        0.87      0.87      0.87        15
#           s        0.88      0.92      0.90        25
#
#     accuracy                           0.88        65
#    macro avg       0.85      0.90      0.87        65
# weighted avg       0.88      0.88      0.88        65
#
# {('C:', 5, ' Kernel: ', 'rbf', ' Gamma: ', 'scale'): 0.8769230769230769}

# %%
plt.figure(figsize=(10,10))

plt.plot(x_scale, y_scale,marker='x',label='Scale' )
# plt.plot(x_auto, y_auto,marker='o',label='Auto' )

plt.ylabel('Test Accruacy') 
plt.xlabel('Cost') 


plt.show()

# %%
eval_model(best, X_train, Y_train, X_val, Y_val, True)
# Out:
#               precision    recall  f1-score   support
#
#           d        0.88      0.76      0.82        85
#           h        0.74      0.76      0.75        33
#           o        0.79      0.74      0.77        31
#           s        0.82      0.91      0.86       111
#
#     accuracy                           0.82       260
#    macro avg       0.81      0.79      0.80       260
# weighted avg       0.83      0.82      0.82       260
# '0.823076923076923'

# %% [markdown]
# ## One vs. ALL

# %%
onevsall_svm = OneVsRestClassifier(SVC(class_weight='balanced'))
print(onevsall_svm)
onevsall_svm.fit(X_train, Y_train)
eval_model(onevsall_svm, X_train, Y_train, X_test, Y_test, True)

predicted_svm = onevsall_svm.predict(X_val)
accur_svm = accuracy_score(Y_val, predicted_svm)
print(accur_svm)
# Out:
# OneVsRestClassifier(estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                                   class_weight='balanced', coef0=0.0,
#                                   decision_function_shape='ovr', degree=3,
#                                   gamma='scale', kernel='rbf', max_iter=-1,
#                                   probability=False, random_state=None,
#                                   shrinking=True, tol=0.001, verbose=False),
#                     n_jobs=None)
#               precision    recall  f1-score   support
#
#           d        0.88      0.75      0.81        20
#           h        0.62      1.00      0.77         5
#           o        1.00      0.80      0.89        15
#           s        0.82      0.92      0.87        25
#
#     accuracy                           0.85        65
#    macro avg       0.83      0.87      0.83        65
# weighted avg       0.87      0.85      0.85        65
#
# 0.8076923076923077

# %% [markdown]
# Lets optimize the hyperparamters for 1vall

# %%
estimator__kernel = ['rbf']
gamma_values = ['scale', 'auto']
accuracy_max = 0
accur_obj = {}
x_scale=[]
y_scale = []

x_auto=[]
y_auto = []




for i in range(1,50):
    for y,gammas in enumerate(gamma_values):
        for x,elem in enumerate(estimator__kernel):
            search = OneVsRestClassifier(SVC(class_weight='balanced', C=i, kernel=elem, gamma=gammas))
            search.fit(X_train, Y_train)
            predicted = search.predict(X_test)
            accur = accuracy_score(Y_test, predicted)
            if(gammas == 'scale'):
                x_scale.append(i)
                y_scale.append(accur)
            else:
                x_auto.append(i)
                y_auto.append(accur)
            if(accur > accuracy_max):
                best2 = search
                accuracy_max = accur
                name = "C:" , i, " Kernel: ", elem , " Gamma: ", gammas
                accur_obj = {name: accuracy_max}
eval_model(best2, X_train, Y_train, X_test, Y_test, True)


print(accur_obj)
# Out:
#               precision    recall  f1-score   support
#
#           d        0.88      0.75      0.81        20
#           h        0.62      1.00      0.77         5
#           o        1.00      0.80      0.89        15
#           s        0.82      0.92      0.87        25
#
#     accuracy                           0.85        65
#    macro avg       0.83      0.87      0.83        65
# weighted avg       0.87      0.85      0.85        65
#
# {('C:', 1, ' Kernel: ', 'rbf', ' Gamma: ', 'scale'): 0.8461538461538461}

# %%
plt.figure(figsize=(10,10))

plt.plot(x_scale, y_scale,marker='x',label='Scale' )
# plt.plot(x_auto, y_auto,marker='o',label='Auto' )

plt.ylabel('Test Accruacy') 
plt.xlabel('n_neighbours') 


plt.show()

# %%
eval_model(best2, X_train, Y_train, X_val, Y_val, True)
# Out:
#               precision    recall  f1-score   support
#
#           d        0.87      0.73      0.79        85
#           h        0.71      0.88      0.78        33
#           o        0.91      0.68      0.78        31
#           s        0.78      0.88      0.83       111
#
#     accuracy                           0.81       260
#    macro avg       0.82      0.79      0.80       260
# weighted avg       0.82      0.81      0.81       260
# '0.8076923076923077'
